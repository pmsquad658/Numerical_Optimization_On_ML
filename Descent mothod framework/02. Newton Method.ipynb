# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Example 1
# \begin{equation}
# f(x) = x^2 - 4x + 6
# \end{equation}

# %%
def f(x):
    return x**2 - 4*x + 6

# f = lambda x: x**2 - 4*x + 6

# %%
NumberOfPoints = 101
x = np.linspace(-5., 5, NumberOfPoints)

# %%
fx = f(x)

# %%
plt.plot(x,fx)
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('plot of f(x)')
plt.show()

# %% [markdown]
# ## Newton  Method

# %% [markdown]
# With initial $x^{(0)}$, calculate the following equation :
# \begin{equation}
# x^{(k+1)} = x^{(k)} - \alpha \nabla^2 f(x^{(k)})^{-1}\nabla f(x^{(k)})
# \end{equation}

# %% [markdown]
# 1. Define $f(x)$ : $ f(x) = x^2 - 4x + 6 $
# 1. Define $\nabla f(x)$, hessian_f(x)
# 1. Tune parameters $x_0$, $\alpha$,MaxIter
# 1. Call `steepest_descent(,,,)`

# %%
def grad_fx(x):
    return 2*x - 4
def hess_f(x):
    return 2.0

# %%
x0 = 0.
MaxIter = 10
for i in range(MaxIter):
#     x1 = x0 - learning_Rate * grad?
    x1 = x0 - grad_fx(x0)/hess_f(x0)
    print(i, x0, f(x0))
    x0 = x1

# 훨씬 빠른 시간 안에 최적점에 도달함
# Out:
# 0 0.0 6.0
# 1 2.0 2.0
# 2 2.0 2.0
# 3 2.0 2.0
# 4 2.0 2.0
# 5 2.0 2.0
# 6 2.0 2.0
# 7 2.0 2.0
# 8 2.0 2.0
# 9 2.0 2.0

# %%
def newton_descent(func, grad_func, hess_fun, x0, learning_rate=1, MaxIter=10, verbose=True):
    paths = []
    for i in range(MaxIter):
        x1 = x0 - learning_rate * grad_func(x0) / hess_fun(x0)
        if verbose:
            print('{0:03d} : {1:4.3f}, {2:4.2E}'.format(i, x0, func(x0)))
        x0 = x1
        paths.append(x0)
    return(x0, func(x0), paths)

# %%
xopt, fopt, paths = newton_descent(f, grad_fx, hess_f, 0.0)
# Out:
# 000 : 0.000, 6.00E+00
# 001 : 2.000, 2.00E+00
# 002 : 2.000, 2.00E+00
# 003 : 2.000, 2.00E+00
# 004 : 2.000, 2.00E+00
# 005 : 2.000, 2.00E+00
# 006 : 2.000, 2.00E+00
# 007 : 2.000, 2.00E+00
# 008 : 2.000, 2.00E+00
# 009 : 2.000, 2.00E+00

# %%
x = np.linspace(0.5, 2.5, 1000)
paths = np.array(paths)
plt.plot(x,f(x))
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('plot of f(x)')

plt.plot(paths, f(paths), 'o-')
plt.show()

# %%
plt.plot(f(paths), 'o-')
plt.grid()
plt.xlabel('x')
plt.ylabel('cost')
plt.title('plot of cost')
plt.show()

# %%
from scipy.optimize import minimize
f = lambda x: x**2 - 4*x + 6
x0 = 0.
minimize(f, x0)

# 여기서의 hess_inv
# Out:
#       fun: 2.0
#  hess_inv: array([[0.5]])
#       jac: array([5.96046448e-08])
#   message: 'Optimization terminated successfully.'
#      nfev: 9
#       nit: 2
#      njev: 3
#    status: 0
#   success: True
#         x: array([2.00000002])

# %%
res = minimize(f, x0)
print(res.x, res.fun)
# Out:
# [2.00000002] 2.0

# %% [markdown]
# ## (Additional) non-convex function
# \begin{equation}
# \min_x x \sin(x)
# \end{equation}
# 1. Define $f(x)$ : loss function
# 1. Define $\nabla f(x)$ : gradient of $f$
# 1. Define $\nabla^2 f(x)$ known as Hessian Matrix of $f$
# 1. Tune parameters : `learning_rate, x0, MaxIter`

# %%
x = np.linspace(-2, 8, 501)
f = lambda x : x * np.sin(x)
grad_f = lambda x: np.sin(x) + x * np.cos(x)
hess_f = lambda x: 2 * np.cos(x) - x * np.sin(x)

# %%
fx = f(x)
plt.plot(x, fx)
plt.grid()
plt.show()

# %%
# x0 = 5.7
# MaxIter = 10
# learning_rate = 1.0
x0 = 5.0
MaxIter = 1000
learning_rate = 0.00250
# x0 = -0.2
# MaxIter = 50
# learning_rate = 0.1250

xopt, fopt, paths = newton_descent(f, grad_fx, hess_f, x0, 
                                   MaxIter=MaxIter, learning_rate=learning_rate, verbose=False)

plt.plot(x,f(x))
plt.grid()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('plot of f(x)')

plt.plot(paths, f(paths), 'o-')
plt.show()
plt.plot(f(paths))
plt.grid()
plt.xlabel('x')
plt.ylabel('cost')
plt.title('plot of cost')
plt.show()

# %%
# 5 에서 시작해서 팅겨져 올라가서 0으로 수렴하였음
paths
# Out:
# [4.9972025080604165,
#  4.994405484354663,
#  4.991608905328055,
#  4.988812747437008,
#  4.986016987147197,
#  4.9832216009317225,
#  4.980426565269267,
#  4.9776318566422635,
#  4.974837451535049,
#  4.972043326432031,
#  4.969249457815839,
#  4.966455822165485,
#  4.963662395954514,
#  4.960869155649154,
#  4.958076077706464,
#  4.955283138572476,
#  4.952490314680333,
#  4.949697582448429,
#  4.946904918278527,
#  4.944112298553894,
#  4.941319699637413,
#  4.938527097869696,
#  4.93573446956719,
#  4.932941791020271,
#  4.930149038491342,
#  4.927356188212905,
#  4.9245632163856445,
#  4.921770099176485,
#  4.918976812716652,
#  4.916183333099713,
#  4.913389636379617,
#  4.910595698568717,
#  4.907801495635784,
#  4.905007003504009,
#  4.902212198048992,
#  4.89941705509672,
#  4.89662155042153,
#  4.893825659744062,
#  4.891029358729188,
#  4.888232622983942,
#  4.8854354280554215,
#  4.882637749428677,
#  4.879839562524591,
#  4.877040842697729,
#  4.874241565234187,
#  4.8714417053494055,
#  4.86864123818598,
#  4.865840138811442,
#  4.863038382216025,
#  4.860235943310409,
#  4.857432796923445,
#  4.854628917799856,
#  4.851824280597919,
#  4.849018859887121,
#  4.846212630145794,
#  4.843405565758724,
#  4.840597641014739,
#  4.837788830104264,
#  4.834979107116861,
#  4.832168446038731,
#  4.829356820750195,
#  4.826544205023144,
#  4.823730572518465,
#  4.8209158967834265,
#  4.818100151249046,
#  4.815283309227414,
#  4.812465343909,
#  4.809646228359909,
#  4.806825935519114,
#  4.804004438195656,
#  4.8011817090657996,
#  4.7983577206701575,
#  4.795532445410778,
#  4.792705855548189,
#  4.789877923198409,
#  4.7870486203299105,
#  4.78421791876055,
#  4.781385790154449,
#  4.77855220601883,
#  4.775717137700817,
#  4.772880556384181,
#  4.770042433086042,
#  4.767202738653522,
#  4.7643614437603485,
#  4.7615185189034115,
#  4.75867393439926,
#  4.755827660380554,
#  4.752979666792457,
#  4.750129923388972,
#  4.747278399729226,
#  4.744425065173689,
#  4.741569888880337,
#  4.738712839800749,
#  4.735853886676152,
#  4.276772531322321,
#  4.273019724729499,
#  4.26925199499512,
#  4.265469073954989,
#  4.2616706861974585,
#  4.2578565487822315,
#  4.254026370945044,
#  4.2501798537873405,
#  4.246316689950001,
#  4.242436563270117,
#  4.23853914841971,
#  4.234624110525235,
#  4.230691104766604,
#  4.226739775954344,
#  4.222769758083454,
#  4.218780673862342,
#  4.214772134215126,
#  4.210743737755456,
#  4.206695070229807,
#  4.202625703928087,
#  4.198535197059155,
#  4.194423093088688,
#  4.190288920036566,
#  4.186132189730727,
#  4.181952397014143,
#  4.177749018901274,
#  4.1735215136800035,
#  4.169269319954711,
#  4.1649918556256695,
#  4.16068851679955,
#  4.156358676625238,
#  4.152001684048628,
#  4.147616862479408,
#  4.143203508362101,
#  4.138760889642839,
#  4.134288244122437,
#  4.129784777685272,
#  4.125249662392371,
#  4.120682034425746,
#  4.116080991869574,
#  4.111445592312122,
#  4.106774850250412,
#  4.102067734277454,
#  4.0973231640293655,
#  4.09254000686689,
#  4.087717074262533,
#  4.082853117860798,
#  4.077946825174669,
#  4.072996814876476,
#  4.068001631635483,
#  4.062959740447758,
#  4.057869520396024,
#  4.052729257767923,
#  4.047537138450295,
#  4.042291239504281,
#  4.036989519810894,
#  4.031629809658753,
#  4.026209799124184,
#  4.0207270250682345,
#  4.0151788565442015,
#  4.009562478371932,
#  4.003874872589747,
#  3.9981127974394277,
#  3.9922727634716866,
#  3.986351006275519,
#  3.980343455230515,
#  3.974245697550731,
#  3.9680529367245234,
#  3.9617599442464844,
#  3.95536100327156,
#  3.9488498424785523,
#  3.942219557984558,
#  3.9354625205670306,
#  3.928570264674818,
#  3.9215333546702356,
#  3.9143412223345506,
#  3.9069819677323148,
#  3.8994421128309162,
#  3.891706293452579,
#  3.8837568696401035,
#  3.8755734264605297,
#  3.8671321252132875,
#  3.858404846546122,
#  3.8493580379723973,
#  3.839951131356909,
#  3.8301343174673352,
#  3.8198453283641203,
#  3.8090046308031202,
#  3.797507959913808,
#  3.78521415646076,
#  3.771924144651497,
#  3.757341731956579,
#  3.740992739956806,
#  3.7220327305164553,
#  3.69867934376607,
#  3.665753016267831,
#  3.5850245434172394,
#  3.6145470778574893,
#  3.674809294516722,
#  3.617285306251085,
#  3.683895040162789,
#  3.6391694867911237,
#  4.038644473330552,
#  4.033303038995318,
#  4.027902038445473,
#  4.022439057676867,
#  4.016911519600071,
#  4.011316668213485,
#  4.005651550749429,
#  3.999912997467082,
#  3.9940975987024108,
#  3.988201678706537,
#  3.9822212657065803,
#  3.976152057501369,
#  3.9699893817516534,
#  3.963728149931208,
#  3.957362803658862,
#  3.9508872518149207,
#  3.9442947964350976,
#  3.9375780448381823,
#  3.9307288047342337,
#  3.923737958112474,
#  3.9165953084275893,
#  3.9092893938509885,
#  3.9018072569229743,
#  3.8941341575193986,
#  3.8862532111479724,
#  3.8781449274510917,
#  3.8697866131801204,
#  3.8611515877765354,
#  3.8522081345630044,
#  3.842918070275453,
#  3.8332347490485548,
#  3.823100202667368,
#  3.812440914307951,
#  3.8011613381125398,
#  3.7891335086631774,
#  3.776179436157205,
#  3.7620391149860763,
#  3.746306787126942,
#  3.728286792516447,
#  3.7066002486780003,
#  3.677716638894485,
#  3.6250297347091736,
#  3.7197282567848418,
#  3.695691565020556,
#  3.660920842934817,
#  3.5578841365440037,
#  3.5778323092127526,
#  3.604047628956505,
#  3.64811816365631,
#  3.2554174594801215,
#  3.259298648799013,
#  3.2632255937880608,
#  3.26719978617471,
#  3.2712228003743133,
#  3.275296300033609,
#  3.2794220452541634,
#  3.2836019005840638,
#  3.2878378438800033,
#  3.292131976158333,
#  3.296486532573206,
#  3.3009038946833034,
#  3.3053866041966837,
#  3.309937378417098,
#  3.3145591276560786,
#  3.3192549749249847,
#  3.3240282782822126,
#  3.3288826562859226,
#  3.333822017095633,
#  3.3388505918819233,
#  3.3439729733488104,
#  3.349194160356902,
#  3.354519609868975,
#  3.3599552977391642,
#  3.365507790254436,
#  3.371184328842859,
#  3.3769929310300193,
#  3.3829425116133485,
#  3.3890430292212845,
#  3.3953056650573985,
#  3.401743042887763,
#  3.4083695024979974,
#  3.415201443363012,
#  3.422257761825695,
#  3.4295604147757586,
#  3.437135157476148,
#  3.4450125258825115,
#  3.4532291699227526,
#  3.4618297034882106,
#  3.470869337685675,
#  3.480417742422576,
#  3.4905649130632592,
#  3.501430471078931,
#  3.5131792012424334,
#  3.5260487775655744,
#  3.540403677319347,
#  3.5568530130485856,
#  3.5765556283937325,
#  3.6022580792562118,
#  3.6443893711045754,
#  1.406804560372262,
#  1.4040101980785047,
#  1.401178891106514,
#  1.3983094913515204,
#  1.3954007907840338,
#  1.3924515169984657,
#  1.3894603283285478,
#  1.3864258084769723,
#  1.3833464605989805,
#  1.3802207007705982,
#  1.3770468507615838,
#  1.3738231300206132,
#  1.3705476467653435,
#  1.3672183880522957,
#  1.3638332086803384,
#  1.3603898187561614,
#  1.3568857697195158,
#  1.353318438588911,
#  1.349685010143307,
#  1.3459824567000849,
#  1.3422075150815616,
#  1.3383566602781212,
#  1.3344260752111419,
#  1.3304116158673611,
#  1.3263087709102186,
#  1.322112614662377,
#  1.3178177520825851,
#  1.313418254009489,
#  1.3089075804874215,
#  1.3042784893860868,
#  1.2995229267226793,
#  1.2946318940126407,
#  1.2895952864990143,
#  1.2844016940697773,
#  1.279038153810432,
#  1.2734898390602418,
#  1.267739663924513,
#  1.2617677734468686,
#  1.2555508764265666,
#  1.2490613574053322,
#  1.2422660718085494,
#  1.2351246748605373,
#  1.2275872442413471,
#  1.2195907960682628,
#  1.211053996198713,
#  1.2018687845909677,
#  1.191886402276837,
#  1.1808925013087295,
#  1.1685588640770075,
#  1.1543382562828894,
#  1.1371936677030245,
#  1.1146860603478959,
#  1.0777412841021603,
#  -0.6088744836775581,
#  -0.598780892697223,
#  -0.5888962314290045,
#  -0.5792073206043354,
#  -0.569702284193931,
#  -0.5603703755197808,
#  -0.5512018321328049,
#  -0.5421877538395948,
#  -0.5333199995145995,
#  -0.5245910992749647,
#  -0.5159941793093262,
#  -0.5075228971992529,
#  -0.4991713859955384,
#  -0.49093420564201967,
#  -0.4828063005995696,
#  -0.47478296272896303,
#  -0.4668597986557867,
#  -0.4590327009727227,
#  -0.45129782274139696,
#  -0.44365155484290225,
#  -0.43609050579719955,
#  0.3734626469664649,
#  0.37817483173695465,
#  0.38289204905481355,
#  0.3876145640076565,
#  0.392342646103662,
#  0.3970765694769027,
#  0.4018166131013728,
#  0.4065630610142489,
#  0.4113162025489542,
#  0.4160763325786379,
#  0.4208437517707222,
#  0.42561876685321626,
#  0.4304016908935467,
#  0.4351928435907078,
#  0.43999255158159417,
#  0.44480114876244164,
#  0.4496189766263736,
#  0.45444638461812426,
#  0.45928373050709353,
#  0.4641313807799794,
#  0.46898971105433096,
#  0.47385910651447416,
#  0.4787399623713796,
#  0.48363268434817175,
#  0.48853768919311996,
#  0.49345540522210846,
#  0.4983862728927524,
#  0.5033307454125168,
#  0.5082892893834019,
#  0.5132623854859888,
#  0.51825052920589,
#  0.5232542316059335,
#  0.5282740201477153,
#  0.5333104395665016,
#  0.5383640528038446,
#  0.5434354420026998,
#  0.548525209570308,
#  0.5536339793146343,
#  0.5587623976607463,
#  0.5639111349541784,
#  0.5690808868590708,
#  0.5742723758597053,
#  0.5794863528750024,
#  0.5847235989966015,
#  0.5899849273623455,
#  0.5952711851783451,
#  0.6005832559043401,
#  0.6059220616188215,
#  0.6112885655823739,
#  0.6166837750199767,
#  0.622108744145609,
#  0.6275645774554988,
#  0.6330524333198024,
#  0.6385735279064774,
#  0.6441291394757106,
#  0.6497206130886071,
#  0.6553493657800556,
#  0.6610168922529477,
#  0.6667247711594233,
#  0.6724746720448138,
#  0.6782683630417312,
#  0.6841077194157138,
#  0.6899947330804185,
#  0.6959315232201432,
#  0.7019203481811845,
#  0.7079636188220869,
#  0.7140639135473782,
#  0.7202239952913618,
#  0.7264468307698221,
#  0.7327356123805032,
#  0.739093783211072,
#  0.7455250657100545,
#  0.7520334946973399,
#  0.7586234555434225,
#  0.7652997285402031,
#  0.7720675407338773,
#  0.7789326268099255,
#  0.7859013010360049,
#  0.7929805428148163,
#  0.8001780991241868,
#  0.8075026080949642,
#  0.8149637492995984,
#  0.822572428144102,
#  0.8303410042964501,
#  0.8382835776861199,
#  0.8464163508035164,
#  0.8547580936606329,
#  0.8633307492266882,
#  0.8721602347406638,
#  0.8812775220289251,
#  0.8907201249752239,
#  0.900534197895201,
#  0.9107775805695022,
#  0.9215243668401354,
#  0.9328720384594774,
#  0.9449531612368183,
#  0.9579557655967252,
#  0.9721617552397508,
#  0.9880272988853843,
#  1.0063780495037244,
#  1.0290056130898098,
#  1.0614361112319763,
#  1.158108182065435,
#  1.141838727597803,
#  1.121064206891375,
#  1.0897052240278589,
#  0.9773785486616987,
#  0.9939733433606708,
#  1.0135018143721533,
#  1.0384592575270617,
#  1.0784115361287754,
#  0.12781578359819346,
#  0.13257381691169373,
#  0.1373257175602487,
#  0.14207169375524556,
#  0.1468119524517808,
#  0.15154669943457721,
#  0.1562761394029646,
#  0.16100047605502238,
#  0.1657199121709803,
#  0.17043464969597227,
#  0.1751448898222379,
#  0.17985083307086455,
#  0.18455267937316333,
#  0.1892506281517704,
#  0.19394487840156674,
#  0.19863562877050775,
#  0.2033230776404555,
#  0.20800742320810633,
#  0.2126888635661069,
#  0.21736759678445358,
#  0.22204382099227019,
#  0.22671773446006055,
#  0.23138953568253454,
#  0.23605942346210726,
#  0.24072759699317337,
#  0.24539425594726083,
#  0.2500596005591708,
#  0.25472383171421326,
#  0.2593871510366509,
#  0.2640497609794676,
#  0.26871186491558074,
#  0.27337366723062173,
#  0.27803537341741213,
#  0.28269719017226913,
#  0.28735932549327764,
#  0.29202198878067315,
#  0.2966853909394846,
#  0.3013497444845934,
#  0.30601526364837184,
#  0.3106821644910708,
#  0.315350665014136,
#  0.3200209852766395,
#  0.32469334751502316,
#  0.32936797626636033,
#  0.33404509849535374,
#  0.3387249437252974,
#  0.3434077441732442,
#  0.3480937348896345,
#  0.35278315390265286,
#  0.3574762423675989,
#  0.3621732447215726,
#  0.36687440884379224,
#  0.37157998622188365,
#  0.3762902321244988,
#  0.38100540578064507,
#  0.3857257705661295,
#  0.39045159419754905,
#  0.3951831489342854,
#  0.39992071178899313,
#  0.4046645647471022,
#  0.4094149949958918,
#  0.41417229516372955,
#  0.4189367635701123,
#  0.42370870448718845,
#  0.42848842841349094,
#  0.43327625236066186,
#  0.4380725001540072,
#  0.44287750274778187,
#  0.4476915985561725,
#  0.45251513380101943,
#  0.45734846287739783,
#  0.4621919487382676,
#  0.4670459632994936,
#  0.4719108878666453,
#  0.47678711358509557,
#  0.4816750419150654,
#  0.4865750851333969,
#  0.49148766686398687,
#  0.49641322263897836,
#  0.5013522004929892,
#  0.5063050615928562,
#  0.5112722809055918,
#  0.5162543479074995,
#  0.521251767337653,
#  0.5262650599992538,
#  0.5312947636127018,
#  0.5363414337245865,
#  0.5414056446772115,
#  0.5464879906437191,
#  0.5515890867343884,
#  0.5567095701802462,
#  0.5618501016007618,
#  0.5670113663631073,
#  0.5721940760412623,
#  0.5773989699841338,
#  0.5826268170028788,
#  0.58787841718875,
#  0.593154603874081,
#  0.5984562457504861,
#  0.6037842491600134,
#  0.6091395605768821,
#  0.6145231692995933,
#  0.6199361103756739,
#  0.6253794677841479,
#  0.630854377904083,
#  0.6363620333013169,
#  0.6419036868698043,
#  0.6474806563690574,
#  0.6530943294049983,
#  0.6587461689083579,
#  0.6644377191727362,
#  0.6701706125237992,
#  0.6759465767021142,
#  0.6817674430551665]

# %% [markdown]
# ## Example 02
# \begin{equation}
# f(x, y) = (x-2)^2 + (y-2)^2
# \end{equation}

# %% [markdown]
# Contour

# %%
xmin, xmax, xstep = -4.0, 4.0, .25
ymin, ymax, ystep = -4.0, 4.0, .25

# %%
x, y = np.meshgrid(np.arange(xmin, xmax + xstep, xstep), np.arange(ymin, ymax + ystep, ystep))

# %%
f = lambda x,y : (x-2)**2 + (y-2)**2

# %%
z = f(x, y)

# %%
minima = np.array([2., 2.])

# %%
f(*minima)
# Out:
# 0.0

# %%
minima_ = minima.reshape(-1, 1)

# %%
from visualize import surf

# %%
surf(f, x, y, minima=minima_)

# %%
from visualize import contour_with_quiver

# %%
grad_f_x = lambda x, y: 2 * (x-2)
grad_f_y = lambda x, y: 2 * (y-2)

# %%
hessian_f = lambda x, y: np.array([[2.0, 0.0],[0.0, 2.0]])
# 손으로 구해서 matrix 를 사전 정의하였음

# %%
x0 = np.array([-2., -2.])
MaxIter = 10
learning_rate = 1
for i in range(MaxIter):
    grad = np.array([grad_f_x(*x0), grad_f_y(*x0)])
    hess = hessian_f(*x0)   # 손으로 미리 구한 matrix
    x1 = x0 - learning_rate * np.linalg.solve(hess, grad)# Key points # hess 와 grad dot 이 계산
    fval = f(*x0)
    print(i, x0, fval)
    x0 = x1
# Out:
# 0 [-2. -2.] 32.0
# 1 [2. 2.] 0.0
# 2 [2. 2.] 0.0
# 3 [2. 2.] 0.0
# 4 [2. 2.] 0.0
# 5 [2. 2.] 0.0
# 6 [2. 2.] 0.0
# 7 [2. 2.] 0.0
# 8 [2. 2.] 0.0
# 9 [2. 2.] 0.0

# %%
def newton_descent_2d(func, gradx, grady, hessian, x0, MaxIter=10, learning_rate=1, verbose=True):
    paths = [x0]
    fval_paths = [f(x0[0], x0[1])]
    for i in range(MaxIter):
        grad = np.array([grad_f_x(*x0), grad_f_y(*x0)])
        hess = hessian(*x0)
        x1 = x0 - learning_rate * np.linalg.solve(hess, grad)
        fval = f(*x0)
        if verbose:
            print(i, x0, fval)
        x0 = x1
        paths.append(x0)
        fval_paths.append(fval)
    paths = np.array(paths)
    paths = np.array(np.matrix(paths).T)
    fval_paths = np.array(fval_paths)
    return(x0, fval, paths, fval_paths)

# %%
x0 = np.array([-2., -2.])
xopt, fopt, paths, fval_paths = newton_descent_2d(f, grad_f_x, grad_f_y, hessian_f, x0)
# Out:
# 0 [-2. -2.] 32.0
# 1 [2. 2.] 0.0
# 2 [2. 2.] 0.0
# 3 [2. 2.] 0.0
# 4 [2. 2.] 0.0
# 5 [2. 2.] 0.0
# 6 [2. 2.] 0.0
# 7 [2. 2.] 0.0
# 8 [2. 2.] 0.0
# 9 [2. 2.] 0.0

# %%
from visualize import contour_with_path

# %%
contour_with_path(f, x, y, paths, minima=np.array([[2],[2]]))
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\contour.py:1537: UserWarning: Log scale: values of z <= 0 have been masked
#   warnings.warn('Log scale: values of z <= 0 have been masked')

# %% [markdown]
# ## Example 03
# \begin{equation}
# f(x, y) = 3(x-2)^2 + (y-2)^2
# \end{equation}

# %%
f = lambda x,y : 3*(x-2)**2 + (y-2)**2

# %%
grad_f_x = lambda x, y: 6 * (x-2)
grad_f_y = lambda x, y: 2 * (y-2)

hessian_f = lambda x, y: np.array([[6.0, 0.0],[0.0, 2.0]])

# %%
xopt, fopt, paths, fval_paths = newton_descent_2d(f, grad_f_x, grad_f_y, hessian_f, x0)
# Out:
# 0 [-2. -2.] 64.0
# 1 [2. 2.] 0.0
# 2 [2. 2.] 0.0
# 3 [2. 2.] 0.0
# 4 [2. 2.] 0.0
# 5 [2. 2.] 0.0
# 6 [2. 2.] 0.0
# 7 [2. 2.] 0.0
# 8 [2. 2.] 0.0
# 9 [2. 2.] 0.0

# %%
contour_with_path(f, x, y, paths, minima=np.array([[2],[2]]))
# Out:
# C:\Anaconda3\lib\site-packages\matplotlib\contour.py:1537: UserWarning: Log scale: values of z <= 0 have been masked
#   warnings.warn('Log scale: values of z <= 0 have been masked')

# %% [markdown]
# ### Steepest Descent vs. Newton Method

# %%
from numerical_optimizers import steepest_descent_2d
x0 = np.array([-3., -3.])
learning_rate = 1
xopt, fopt, paths, fval_paths = steepest_descent_2d(f, grad_f_x, grad_f_y, x0, 
                                                    learning_rate=learning_rate)
contour_with_path(f, x, y, paths, minima=np.array([[2],[2]]))
# Out:
# 0 [-3. -3.] 100.0
# 1 [27.  7.] 1900.0
# 2 [-123.   -3.] 46900.0
# 3 [627.   7.] 1171900.0
# 4 [-3.123e+03 -3.000e+00] 29296900.0
# 5 [1.5627e+04 7.0000e+00] 732421900.0
# 6 [-7.8123e+04 -3.0000e+00] 18310546900.0
# 7 [3.90627e+05 7.00000e+00] 457763671900.0
# 8 [-1.953123e+06 -3.000000e+00] 11444091796900.0
# 9 [9.765627e+06 7.000000e+00] 286102294921900.0
# C:\Anaconda3\lib\site-packages\matplotlib\contour.py:1537: UserWarning: Log scale: values of z <= 0 have been masked
#   warnings.warn('Log scale: values of z <= 0 have been masked')

# %%
from numerical_optimizers import steepest_descent_2d
x0 = np.array([-3., -3.])
learning_rate = 0.25
xopt, fopt, paths, fval_paths = steepest_descent_2d(f, grad_f_x, grad_f_y, x0, 
                                                    learning_rate=learning_rate)
contour_with_path(f, x, y, paths, minima=np.array([[2],[2]]))
# Out:
# 0 [-3. -3.] 100.0
# 1 [ 4.5 -0.5] 25.0
# 2 [0.75 0.75] 6.25
# 3 [2.625 1.375] 1.5625
# 4 [1.6875 1.6875] 0.390625
# 5 [2.15625 1.84375] 0.09765625
# 6 [1.921875 1.921875] 0.0244140625
# C:\Anaconda3\lib\site-packages\matplotlib\contour.py:1537: UserWarning: Log scale: values of z <= 0 have been masked
#   warnings.warn('Log scale: values of z <= 0 have been masked')
# 7 [2.0390625 1.9609375] 0.006103515625
# 8 [1.98046875 1.98046875] 0.00152587890625
# 9 [2.00976562 1.99023438] 0.0003814697265625

# %%
x0 = np.array([-2., -3.])
learning_rate = 1.0
xopt, fopt, paths, fval_paths = newton_descent_2d(f, grad_f_x, grad_f_y, hessian_f, x0,
                                                 learning_rate=learning_rate)
contour_with_path(f, x, y, paths, minima=np.array([[2],[2]]))
# Out:
# 0 [-2. -3.] 73.0
# 1 [2. 2.] 0.0
# 2 [2. 2.] 0.0
# 3 [2. 2.] 0.0
# 4 [2. 2.] 0.0
# 5 [2. 2.] 0.0
# C:\Anaconda3\lib\site-packages\matplotlib\contour.py:1537: UserWarning: Log scale: values of z <= 0 have been masked
#   warnings.warn('Log scale: values of z <= 0 have been masked')
# 6 [2. 2.] 0.0
# 7 [2. 2.] 0.0
# 8 [2. 2.] 0.0
# 9 [2. 2.] 0.0

# %%
x0 = np.array([-2., -3.])
learning_rate = 0.5
xopt, fopt, paths, fval_paths = newton_descent_2d(f, grad_f_x, grad_f_y, hessian_f, x0,
                                                 learning_rate=learning_rate)
contour_with_path(f, x, y, paths, minima=np.array([[2],[2]]))
# Out:
# 0 [-2. -3.] 73.0
# 1 [ 0.  -0.5] 18.25
# 2 [1.   0.75] 4.5625
# 3 [1.5   1.375] 1.140625
# 4 [1.75   1.6875] 0.28515625
# 5 [1.875   1.84375] 0.0712890625
# 6 [1.9375   1.921875] 0.017822265625
# 7 [1.96875   1.9609375] 0.00445556640625
# 8 [1.984375   1.98046875]
# C:\Anaconda3\lib\site-packages\matplotlib\contour.py:1537: UserWarning: Log scale: values of z <= 0 have been masked
#   warnings.warn('Log scale: values of z <= 0 have been masked')
# 0.0011138916015625
# 9 [1.9921875  1.99023438] 0.000278472900390625

# %%
# 속도 면에서는 월등히 빠른 성능을 보인다
